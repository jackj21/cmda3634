# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
import mpl_toolkits.mplot3d.axes3d as p3

from IPython.display import HTML
import matplotlib.animation as animation
# Out:
# Matplotlib created a temporary config/cache directory at /tmp/matplotlib-gfadscii because the default path (/home/jovyan/.cache/matplotlib) is not a writable directory; it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.

# %%
def animate_wave_simulation_2D(U):

    fig = plt.figure()

    cmin, cmax = U[0].min(), U[0].max()
    for u in U:
        cmin = min(cmin, u.min())
        cmax = max(cmax, u.max())

    cmin = max(-1, cmin)
    cmax = min(1, cmax)

    im = plt.imshow(U[0], clim=(cmin,cmax), cmap='gray')
    def animate(i):
        im.set_data(U[i])
        return (im,)

    ani = animation.FuncAnimation(fig, animate, interval=50, repeat_delay=1000)

    return ani

# %%
xy = np.linspace(0,4*3.14159,50)
XX, YY = np.meshgrid(xy, xy)

vals = []

for t in np.linspace(0,1,150):
    vals.append(np.sin(t*XX)*np.cos(t*YY))

for t in np.linspace(1,0,150):
    vals.append(np.sin(t*XX)*np.cos(t*YY))

# %%
animate_wave_simulation_2D(vals)
# Out:
# <img src="data:image/png;base64,..." width="1295.30873347921">

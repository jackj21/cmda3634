# %%
# Code for log-log plot Python script
# Jack Jiang
# CMDA 3634
# 3/22/21

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Matplotlib created a temporary config/cache directory at /localscratch/118984/matplotlib-1l_nmc7k because the default path (/home/jovyan/.cache/matplotlib) is not a writable directory; it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.

# %%
pi = pd.read_csv("pi_omp_script.csv", index_col=0,sep=', ', engine='python')
pi_clean = pd.DataFrame({'N':pi.N,
                        'Time':pi.Time})

pi_clean
# Out:
#              N      Time
# T
# 1         1024  0.000042
# 1         8192  0.000244
# 1        65536  0.001744
# 1       524288  0.013861
# 1      4194304  0.110687
# ..         ...       ...
# 64      524288  0.019447
# 64     4194304  0.023830
# 64    33554432  0.047561
# 64   268435456  0.171887
# 64  2147483648  1.281141
#
# [64 rows x 2 columns]

# %%
fig, ax = plt.subplots(figsize=(8,6))
for idx, gp in pi_clean.groupby(pi.index):
    gp.plot(x='N',y='Time',ax=ax,label=idx)

#ax = pi_clean.plot(x='N',y='Time',loglog=True, use_index=False, title='Times for Approximations of PI for N(T)')
#ax.legend(pi_clean.index)
ax.set_ylabel('Time')
ax.legend(title='Number of Threads')
ax.set_title('Time for Approximations of Pi of N(T)')
plt.show()
